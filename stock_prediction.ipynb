# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('new_train.csv')
data.head()
# Out:
#          Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0  2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1  2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2  2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3  2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4  2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# 0       1855.75          568273   105457457545000        285.40        285.95
# 1       1842.82          945167   174177161135000        284.00        284.80
# 2       1893.91          679689   128727119355000        283.00        286.85
# 3       1889.21          509435    96242800140000        288.85        291.80
# 4       1873.32          961913   180196832650000        285.00        289.10
#
#    ...  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  Open-Stock-5  \
# ...

# %%
x=pd.DataFrame(data, columns=['Open-Stock-1','High-Stock-1','Low-Stock-1','VWAP-Stock-1','Volume-Stock-1','Turnover-Stock-1'])
y=pd.DataFrame(data, columns=['Close-Stock-1'])
x.head()
# Out:
#    Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  Volume-Stock-1  \
# 0        1889.7       1890.00      1838.00       1855.75          568273
# 1        1848.0       1862.75      1828.00       1842.82          945167
# 2        1864.1       1910.00      1864.10       1893.91          679689
# 3        1906.0       1909.80      1880.10       1889.21          509435
# 4        1867.0       1894.85      1808.35       1873.32          961913
#
#    Turnover-Stock-1
# 0   105457457545000
# 1   174177161135000
# 2   128727119355000
# 3    96242800140000
# 4   180196832650000

# %%
import matplotlib.pyplot as plt
plt.plot(x);

# %%
y.head()
# Out:
#    Close-Stock-1
# 0        1855.10
# 1        1853.05
# 2        1905.60
# 3        1885.70
# 4        1876.65

# %%
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train=scalar.fit_transform(x_train)
x_test=scalar.fit_transform(x_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

# %%
reg = GradientBoostingRegressor(random_state=1)
reg.fit(x_train,y_train.values.ravel())
# Out:
# GradientBoostingRegressor(random_state=1)

# %%
y_pred= np.round(reg.predict(x_test))
y_pred
# Out:
# array([1993., 2368., 2119., 2370., 2407., 2362., 2144., 2194., 2149.,
#        1986., 2536., 2382., 2430., 2335., 2203., 2146., 2441., 2145.,
#        2497., 1855., 1933., 2347., 1916., 2128., 2004., 2296., 1885.,
#        2383., 2232., 2177., 1856., 2331.,  483., 2330., 2384., 1857.,
#        1858., 2331., 2167.,  487., 2394., 2423., 2145., 1922., 2177.,
#        2129., 2555., 2282., 1855., 2278., 2341., 2040., 2348., 2272.,
#        2308., 2358., 2175., 2062., 2328., 2249.])

# %%
import numpy as np
np.round(reg.score(x_test, y_test.values.ravel()))
# Out:
# 1.0

# %%
np.round(mean_squared_error(y_test, y_pred))
# Out:
# 1500.0

# %%
np.round(mean_squared_error(y_test, y_pred, squared=False))
# Out:
# 39.0

# %%
data=pd.read_csv('new_train.csv')
data.head()
# Out:
#          Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0  2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1  2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2  2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3  2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4  2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# 0       1855.75          568273   105457457545000        285.40        285.95
# 1       1842.82          945167   174177161135000        284.00        284.80
# 2       1893.91          679689   128727119355000        283.00        286.85
# 3       1889.21          509435    96242800140000        288.85        291.80
# 4       1873.32          961913   180196832650000        285.00        289.10
#
#    ...  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  Open-Stock-5  \
# ...

# %%
data1=pd.DataFrame(data, columns=['Open-Stock-1','High-Stock-1','Low-Stock-1','VWAP-Stock-1','Volume-Stock-1','Turnover-Stock-1'])

# %%
x_train1=scalar.fit_transform(data1)

# %%
y_pred1=np.round(reg.predict(x_train1))

# %%
data2=pd.DataFrame(data, columns=['Open-Stock-2','High-Stock-2','Low-Stock-2','VWAP-Stock-2','Volume-Stock-2','Turnover-Stock-2'])
data2.head()
# Out:
#    Open-Stock-2  High-Stock-2  Low-Stock-2  VWAP-Stock-2  Volume-Stock-2  \
# 0        285.40        285.95       281.50        283.72         3191773
# 1        284.00        284.80       279.25        281.05         2704797
# 2        283.00        286.85       282.50        285.34         2489752
# 3        288.85        291.80       277.00        289.81         3188813
# 4        285.00        289.10       285.00        287.01         2198836
#
#    Turnover-Stock-2
# 0    90557243170000
# 1    76017076445000
# 2    71043460510000
# 3    92414802585000
# 4    63109395135000

# %%
x_train2 = scalar.fit_transform(data2)
y_pred2=np.round(reg.predict(x_train2))

# %%
data3=pd.DataFrame(data, columns=['Open-Stock-3','High-Stock-3','Low-Stock-3','VWAP-Stock-3','Volume-Stock-3','Turnover-Stock-3'])
data3.head()
# Out:
#    Open-Stock-3  High-Stock-3  Low-Stock-3  VWAP-Stock-3  Volume-Stock-3  \
# 0       2095.00        2097.8      2045.00       2088.95           70547
# 1       2061.45        2098.0      2023.00       2059.52           55547
# 2       2131.50        2131.5      2091.05       2107.84           55130
# 3       2114.90        2156.0      2095.50       2145.36           29302
# 4       2132.35        2209.0      2112.00       2180.52           78919
#
#    Turnover-Stock-3
# 0    14736933230000
# 1    11440017990000
# 2    11620529360000
# 3     6286330280000
# 4    17208425860000

# %%
x_train3 = scalar.fit_transform(data3)
y_pred3=np.round(reg.predict(x_train3))

# %%
data4=pd.DataFrame(data, columns=['Open-Stock-4','High-Stock-4','Low-Stock-4','VWAP-Stock-4','Volume-Stock-4','Turnover-Stock-4'])
data4.head()
# Out:
#    Open-Stock-4  High-Stock-4  Low-Stock-4  VWAP-Stock-4  Volume-Stock-4  \
# 0        851.65        864.80        833.1        844.44         3878011
# 1        844.70        849.90        823.0        838.31         3320996
# 2        851.40        859.05        848.2        853.51         2494522
# 3        854.10        868.60        854.1        862.85         2963920
# 4        712.00        850.00        712.0        839.89         3471483
#
#    Turnover-Stock-4
# 0   327474904340000
# 1   278403743240000
# 2   212910342645000
# 3   255740999120000
# 4   291567400640000

# %%
x_train4 = scalar.fit_transform(data3)
y_pred4=np.round(reg.predict(x_train4))

# %%
data5=pd.DataFrame(data, columns=['Open-Stock-5','High-Stock-5','Low-Stock-5','VWAP-Stock-5','Volume-Stock-5','Turnover-Stock-5'])
data5.head()
# Out:
#    Open-Stock-5  High-Stock-5  Low-Stock-5  VWAP-Stock-5  Volume-Stock-5  \
# 0        1235.0       1238.00       1177.0       1197.29         1786082
# 1        1195.0       1206.95       1168.5       1189.87         1307410
# 2        1211.0       1248.00       1211.0       1231.63         1482919
# 3        1240.0       1258.00       1240.0       1249.72         1454459
# 4        1218.6       1225.00       1196.0       1209.27         1424594
#
#    Turnover-Stock-5
# 0   213845404410000
# 1   155564994855000
# 2   182640434320000
# 3   181767075850000
# 4   172272511430000

# %%
x_train5 = scalar.fit_transform(data5)
y_pred5=np.round(reg.predict(x_train5))

# %%
output={'Date':data['Date'], 'Close-Stock-1': y_pred1,'Close-Stock-2':y_pred2,'Close-Stock-3':y_pred3,
       'Close-Stock-4':y_pred4,'Close-Stock-5':y_pred5}

result=pd.DataFrame(output)
result
# Out:
#            Date  Close-Stock-1  Close-Stock-2  Close-Stock-3  Close-Stock-4  \
# 0    2010-06-01         1857.0         2558.0          536.0          536.0
# 1    2010-06-02         1856.0         2559.0          536.0          536.0
# 2    2010-06-03         1882.0         2559.0          536.0          536.0
# 3    2010-06-04         1881.0         2558.0          536.0          536.0
# 4    2010-06-07         1856.0         2554.0         1197.0         1197.0
# ..          ...            ...            ...            ...            ...
# 294  2011-07-28          485.0         2207.0         2564.0         2564.0
# 295  2011-07-29          485.0         2251.0         2558.0         2558.0
# 296  2011-08-01          484.0         2265.0         2559.0         2559.0
# 297  2011-08-02          482.0         2239.0         2559.0         2559.0
# 298  2011-08-03          483.0         2249.0         2559.0         2559.0
#
#      Close-Stock-5
# 0           1856.0
# ...

# %%
result.to_csv('Submission.csv', index=False)
